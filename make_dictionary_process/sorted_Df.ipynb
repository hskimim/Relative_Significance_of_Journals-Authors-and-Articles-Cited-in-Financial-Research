# %%
import pandas as pd
import re

# %%
df = pd.read_csv("new_tuned_references.csv")
df.tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 37242  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37243  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37244  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37245  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37246  Corporate Diversification, Relatedness, and Fi...           한국증권학회
#
#            author_infor                                journal_infor  \
# 37242  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37243  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37244  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37245  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37246  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor      page_infor  year_infor field_infor cited_infor  \
# ...

# %%
print(set(df['year_infor']))
# Out:
# {2016, 2017, 2018, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015}

# %%
year_sorted_df = df.sort_values(by='year_infor').reset_index(drop=True)
year_sorted_df.tail()
# Out:
#                           paper_name_infor institution_infor  \
# 37242          현금흐름 위험 기반 KOSPI 수익률 횡단면 연구         한국파생상품학회
# 37243             모호성 회피성향이 예방적 노력에 미치는 영향         한국파생상품학회
# 37244        개별기업의 특성을 반영한 투자자 심리지수와 주식수익률           한국재무학회
# 37245  펀드 자금흐름을 이용한 투자자심리지수 산출의 유용성에 대한 연구           한국재무학회
# 37246         기업의 환경경영과 수익변동성의 관계에 관한 실증연구         한국재무관리학회
#
#            author_infor journal_infor dont_know_infor    page_infor  \
# 37242        문성제 , 송준혁          선물연구           26(3)    pp.311~343
# 37243              홍지민          선물연구           26(3)    pp.371~389
# 37244  류두진 , 류두원 , 양희진          재무연구           31(1)       pp.1~38
# 37245         임경 , 윤선중          재무연구           31(1)     pp.83~115
# 37246        김학건 , 강윤식        재무관리연구           35(2)    pp.183~204
#
#        year_infor field_infor cited_infor char_refer degree_refer  \
# 37242        2018         경영학   피인용횟수 : 0        NaN          NaN
# ...

# %%
journal_sorted_df = df.sort_values('journal_infor').reset_index(drop=True)
journal_sorted_df.tail(1)
# Out:
#               paper_name_infor institution_infor author_infor journal_infor  \
# 37246  발생액 이상현상과 차익거래기회에 관한 연구           한국증권학회    고봉찬 , 김진우       한국증권학회지
#
#       dont_know_infor   page_infor  year_infor field_infor cited_infor  \
# 37246          38(1)    pp.77~105         2009         경영학  피인용횟수 : 13
#
#          char_refer degree_refer  \
# 37246  [학술지(정기간행물)]          NaN
#
#                                            journal_refer name_refer  \
# 37246  Asia-Pacific Journal of Financial Studies 36 (...        고봉찬
#
#              paper_refer school_refer  year_refer  \
# 37246  발생액 이상현상에 대한 위험평가          NaN      2007.0
#
#                                                raw_refer
# 37246  1. [학술지(정기간행물)] - 고봉찬 / 2007 / 발생액 이상현상에 대한 위험...
