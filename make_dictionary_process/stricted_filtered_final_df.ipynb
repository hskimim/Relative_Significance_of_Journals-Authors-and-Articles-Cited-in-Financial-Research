# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
df = pd.read_csv("new_tuned_references.csv")
df.tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 37242  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37243  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37244  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37245  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37246  Corporate Diversification, Relatedness, and Fi...           한국증권학회
#
#            author_infor                                journal_infor  \
# 37242  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37243  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37244  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37245  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37246  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor      page_infor  year_infor field_infor cited_infor  \
# 37242          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37243          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37244          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37245          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37246          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
#
#          char_refer degree_refer                        journal_refer  \
# 37242        [기타자료]          NaN                                  NaN
# 37243  [학술지(정기간행물)]          NaN   Journal of Finance 59 : 479 ~ 506,
# 37244  [학술지(정기간행물)]          NaN    Financial Management 33 : 5 ~ 27,
# 37245  [학술지(정기간행물)]          NaN      St. John’s Review 44 : 66 ~ 80,
# 37246  [학술지(정기간행물)]          NaN  Journal of Finance 56 : 1667 ~ 1691
#
#                name_refer                                        paper_refer  \
# 37242   Villalonga, Belen  Does Diversification Cause the “Diversificatio...
# 37243   Villalonga, Belen  Diversification discount or premium? New Evide...
# 37244   Villalonga, Belen  Does Diversification Cause the Diversification...
# 37245        Weston, J. F  The Nature and Significance of Conglomerate Firms
# 37246      Whited, Toni M  Is It Inefficient Investment That Causes the D...
#
#       school_refer  year_refer
# 37242          NaN      1999.0
# 37243          NaN      2004.0
# 37244          NaN      2004.0
# 37245          NaN      1970.0
# 37246          NaN      2001.0

# %%
Counter(df['char_refer'].values) , len(df)
# Out:
# (Counter({'[학술지(정기간행물)]': 32848,
#           '[기타자료]': 562,
#           '[단행본]': 1084,
#           '[보고서]': 2027,
#           '[학술대회논문]': 385,
#           '[학위논문]': 99,
#           nan: 242}),
#  37247)

# %% [markdown]
# # 학술지 정상 관측치 찾기

# %%
df[df['char_refer'] == '[학술지(정기간행물)]'].isnull().sum()
# Out:
# paper_name_infor         0
# institution_infor        0
# author_infor             0
# journal_infor            0
# dont_know_infor          0
# page_infor               0
# year_infor               0
# field_infor              0
# cited_infor              0
# char_refer               0
# degree_refer         32848
# journal_refer         4661
# name_refer            4220
# paper_refer            230
# school_refer         32848
# year_refer               0
# dtype: int64

# %%
journal_nan_idx = df[df['char_refer'] == '[학술지(정기간행물)]'][df[df['char_refer'] == '[학술지(정기간행물)]']['journal_refer'].isnull()].index.tolist()
journal_nan_idx[:5]
# Out:
# [2973, 9016, 9017, 9018, 9019]

# %%
name_nan_idx = df[df['char_refer'] == '[학술지(정기간행물)]'][df[df['char_refer'] == '[학술지(정기간행물)]']['name_refer'].isnull()].index.tolist()
name_nan_idx[:5]
# Out:
# [9122, 21732, 21733, 21734, 21735]

# %%
paper_nan_idx = df[df['char_refer'] == '[학술지(정기간행물)]'][df[df['char_refer'] == '[학술지(정기간행물)]']['paper_refer'].isnull()].index.tolist()
paper_nan_idx[:5]
# Out:
# [9097, 9100, 9107, 21740, 21756]

# %%
problem_idx = set(journal_nan_idx).union(set(name_nan_idx)).union(paper_nan_idx)
len(problem_idx)
# Out:
# 5386

# %%
normal_idx = sorted(list(set(df[df['char_refer'] == '[학술지(정기간행물)]'].index).difference(set(problem_idx))))
normal_idx[:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
학술지_df = df[df['char_refer'] == '[학술지(정기간행물)]'].loc[normal_idx]
학술지_df.tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 37241  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37243  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37244  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37245  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37246  Corporate Diversification, Relatedness, and Fi...           한국증권학회
#
#            author_infor                                journal_infor  \
# 37241  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37243  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37244  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37245  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37246  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor      page_infor  year_infor field_infor cited_infor  \
# 37241          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37243          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37244          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37245          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37246          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
#
#          char_refer degree_refer                                journal_refer  \
# 37241  [학술지(정기간행물)]          NaN  Journal of Financial Economics 26 : 3 ~ 27,
# 37243  [학술지(정기간행물)]          NaN           Journal of Finance 59 : 479 ~ 506,
# 37244  [학술지(정기간행물)]          NaN            Financial Management 33 : 5 ~ 27,
# 37245  [학술지(정기간행물)]          NaN              St. John’s Review 44 : 66 ~ 80,
# 37246  [학술지(정기간행물)]          NaN          Journal of Finance 56 : 1667 ~ 1691
#
#                name_refer                                        paper_refer  \
# 37241        Stulz, Ren?M  Managerial Direction and Optimal Financing Pol...
# 37243   Villalonga, Belen  Diversification discount or premium? New Evide...
# 37244   Villalonga, Belen  Does Diversification Cause the Diversification...
# 37245        Weston, J. F  The Nature and Significance of Conglomerate Firms
# 37246      Whited, Toni M  Is It Inefficient Investment That Causes the D...
#
#       school_refer  year_refer
# 37241          NaN      1990.0
# 37243          NaN      2004.0
# 37244          NaN      2004.0
# 37245          NaN      1970.0
# 37246          NaN      2001.0

# %%
학술지_df.isnull().sum() , 학술지_df.shape
# Out:
# (paper_name_infor         0
#  institution_infor        0
#  author_infor             0
#  journal_infor            0
#  dont_know_infor          0
#  page_infor               0
#  year_infor               0
#  field_infor              0
#  cited_infor              0
#  char_refer               0
#  degree_refer         27462
#  journal_refer            0
#  name_refer               0
#  paper_refer              0
#  school_refer         27462
#  year_refer               0
#  dtype: int64, (27462, 16))

# %% [markdown]
# # 학술대회논문 정상 관측치 찾기

# %%
df[df['char_refer'] == '[학술대회논문]'].isnull().sum()
# Out:
# paper_name_infor       0
# institution_infor      0
# author_infor           0
# journal_infor          0
# dont_know_infor        0
# page_infor             0
# year_infor             0
# field_infor            0
# cited_infor            0
# char_refer             0
# degree_refer         385
# journal_refer          2
# name_refer             0
# paper_refer            0
# school_refer         385
# year_refer             0
# dtype: int64

# %%
journal_idx1 =sorted(list(set(np.where(df['char_refer'] == '[학술대회논문]')[0].tolist()).intersection(set(np.where(df['journal_refer'].isnull())[0].tolist()))))
journal_idx1
# Out:
# [16358, 29290]

# %%
normal_idx = sorted(list(set(df[df['char_refer'] == '[학술대회논문]'].index).difference(set(journal_idx1))))

# %%
학술대회논문_df = df[df['char_refer'] == '[학술대회논문]'].loc[normal_idx]
학술대회논문_df.tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 36747  An Enhanced Method for Valuation of IT Investm...           한국증권학회
# 36768  An Enhanced Method for Valuation of IT Investm...           한국증권학회
# 36914  An Empirical Study on the Relationship between...           한국증권학회
# 36916  An Empirical Study on the Relationship between...           한국증권학회
# 36917  An Empirical Study on the Relationship between...           한국증권학회
#
#         author_infor                                journal_infor  \
# 36747  Beum-Jo Park    Asia-Pacific Journal of Financial Studies
# 36768  Beum-Jo Park    Asia-Pacific Journal of Financial Studies
# 36914           최정호    Asia-Pacific Journal of Financial Studies
# 36916           최정호    Asia-Pacific Journal of Financial Studies
# 36917           최정호    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor    page_infor  year_infor field_infor cited_infor  \
# 36747          37(4)    pp.727~763      2008.08         경영학   피인용횟수 : 1
# 36768          37(4)    pp.727~763      2008.08         경영학   피인용횟수 : 1
# 36914          37(5)    pp.813~839      2008.10         경영학  피인용횟수 : 41
# 36916          37(5)    pp.813~839      2008.10         경영학  피인용횟수 : 41
# 36917          37(5)    pp.813~839      2008.10         경영학  피인용횟수 : 41
#
#       char_refer degree_refer  \
# 36747   [학술대회논문]          NaN
# 36768   [학술대회논문]          NaN
# 36914   [학술대회논문]          NaN
# 36916   [학술대회논문]          NaN
# 36917   [학술대회논문]          NaN
#
#                                            journal_refer   name_refer  \
# 36747  Proceedings of the 37th Annual Hawaii Internat...   Bardhan, I
# 36768  presented at the 5th annual conference on real...     Gamba, A
# 36914                  기업지배구조 평가결과 활용방안 심포지엄 : 89 ~ 122,          신현한
# 36916                            2004년도 한국회계학회 하계학술발표대회,          이세용
# 36917                            2005년도 한국회계학회 하계학술발표대회,          이화진
#
#                                              paper_refer school_refer  \
# 36747  A real options approach for prioritization of ...          NaN
# 36768  A Log-transformed binomial lattice extension f...          NaN
# 36914  pp.89-122.(Translated in English)Shin,Hyun-Han...          NaN
# 36916                   우리나라의 기업지배구조와 기업가치 사이의 관계에 대한 연구          NaN
# 36917                      기업지배구조가 보고이익의 질과 경영성과에 미치는 영향          NaN
#
#        year_refer
# 36747      2004.0
# 36768      2001.0
# 36914      2004.0
# 36916      2004.0
# 36917      2005.0

# %%
학술대회논문_df.isnull().sum() , 학술대회논문_df.shape
# Out:
# (paper_name_infor       0
#  institution_infor      0
#  author_infor           0
#  journal_infor          0
#  dont_know_infor        0
#  page_infor             0
#  year_infor             0
#  field_infor            0
#  cited_infor            0
#  char_refer             0
#  degree_refer         383
#  journal_refer          0
#  name_refer             0
#  paper_refer            0
#  school_refer         383
#  year_refer             0
#  dtype: int64, (383, 16))

# %% [markdown]
# # 단행본 정상 관측치 찾기

# %%
df[df['char_refer'] == '[단행본]'].tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 37179  Corporate Cash Holdings and Tax-induced Debt F...           한국증권학회
# 37198  Corporate Cash Holdings and Tax-induced Debt F...           한국증권학회
# 37210  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37221  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37238  Corporate Diversification, Relatedness, and Fi...           한국증권학회
#
#            author_infor                                journal_infor  \
# 37179        정구열 , 김병모    Asia-Pacific Journal of Financial Studies
# 37198        정구열 , 김병모    Asia-Pacific Journal of Financial Studies
# 37210  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37221  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37238  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor      page_infor  year_infor field_infor cited_infor  \
# 37179          37(6)     pp.983~1023      2008.12         경영학  피인용횟수 : 10
# 37198          37(6)     pp.983~1023      2008.12         경영학  피인용횟수 : 10
# 37210          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37221          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37238          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
#
#       char_refer degree_refer              journal_refer          name_refer  \
# 37179      [단행본]          NaN            Harcourt Brace,        Keynes, J. M
# 37198      [단행본]          NaN             Prentice-Hall,       Scholes, M. S
# 37210      [단행본]          NaN  Harvard University Press,    Caves, Richard E
# 37221      [단행본]          NaN             Prentice-Hall,   Greene, William H
# 37238      [단행본]          NaN  Harvard University Press,   Rumelt, Richard P
#
#                                              paper_refer school_refer  \
# 37179  The general theory of employment. In: Interest...          NaN
# 37198   Taxes and Business Strategy: a Planning Approach          NaN
# 37210  Competition in the Open Economy: A Model Appli...          NaN
# 37221                  Econometric analysis, 4th edition          NaN
# 37238       Strategy, Structure and Economic Performance          NaN
#
#        year_refer
# 37179      1936.0
# 37198      2002.0
# 37210      1980.0
# 37221      2000.0
# 37238      1974.0

# %%
df[df['char_refer'] == '[단행본]'].isnull().sum()
# Out:
# paper_name_infor        0
# institution_infor       0
# author_infor            0
# journal_infor           0
# dont_know_infor         0
# page_infor              0
# year_infor              0
# field_infor             0
# cited_infor             0
# char_refer              0
# degree_refer         1084
# journal_refer          55
# name_refer              2
# paper_refer             0
# school_refer         1084
# year_refer              0
# dtype: int64

# %%
journal_nan_idx = df[df['char_refer'] == '[단행본]'][df['journal_refer'].isnull()].index.tolist()
len(journal_nan_idx)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 55

# %%
name_nan_idx = df[df['char_refer'] == '[단행본]'][df['name_refer'].isnull()].index.tolist()
len(name_nan_idx)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 2

# %%
paper_nan_idx = df[df['char_refer'] == '[단행본]'][df['paper_refer'].isnull()].index.tolist()
len(paper_nan_idx)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0

# %%
problem_idx = sorted(list(set(journal_nan_idx).union(set(name_nan_idx)).union(set(paper_nan_idx))))
len(problem_idx)
# Out:
# 57

# %%
normal_idx = [i for i in df[df['char_refer'] == '[단행본]'].index if i not in problem_idx]
normal_idx[:5]
# Out:
# [89, 111, 124, 125, 128]

# %%
단행본_df = df[df['char_refer'] == '[단행본]'].loc[normal_idx]
단행본_df.tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 37179  Corporate Cash Holdings and Tax-induced Debt F...           한국증권학회
# 37198  Corporate Cash Holdings and Tax-induced Debt F...           한국증권학회
# 37210  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37221  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37238  Corporate Diversification, Relatedness, and Fi...           한국증권학회
#
#            author_infor                                journal_infor  \
# 37179        정구열 , 김병모    Asia-Pacific Journal of Financial Studies
# 37198        정구열 , 김병모    Asia-Pacific Journal of Financial Studies
# 37210  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37221  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37238  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor      page_infor  year_infor field_infor cited_infor  \
# 37179          37(6)     pp.983~1023      2008.12         경영학  피인용횟수 : 10
# 37198          37(6)     pp.983~1023      2008.12         경영학  피인용횟수 : 10
# 37210          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37221          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37238          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
#
#       char_refer degree_refer              journal_refer          name_refer  \
# 37179      [단행본]          NaN            Harcourt Brace,        Keynes, J. M
# 37198      [단행본]          NaN             Prentice-Hall,       Scholes, M. S
# 37210      [단행본]          NaN  Harvard University Press,    Caves, Richard E
# 37221      [단행본]          NaN             Prentice-Hall,   Greene, William H
# 37238      [단행본]          NaN  Harvard University Press,   Rumelt, Richard P
#
#                                              paper_refer school_refer  \
# 37179  The general theory of employment. In: Interest...          NaN
# 37198   Taxes and Business Strategy: a Planning Approach          NaN
# 37210  Competition in the Open Economy: A Model Appli...          NaN
# 37221                  Econometric analysis, 4th edition          NaN
# 37238       Strategy, Structure and Economic Performance          NaN
#
#        year_refer
# 37179      1936.0
# 37198      2002.0
# 37210      1980.0
# 37221      2000.0
# 37238      1974.0

# %%
단행본_df.isnull().sum() , 단행본_df.shape
# Out:
# (paper_name_infor        0
#  institution_infor       0
#  author_infor            0
#  journal_infor           0
#  dont_know_infor         0
#  page_infor              0
#  year_infor              0
#  field_infor             0
#  cited_infor             0
#  char_refer              0
#  degree_refer         1027
#  journal_refer           0
#  name_refer              0
#  paper_refer             0
#  school_refer         1027
#  year_refer              0
#  dtype: int64, (1027, 16))

# %% [markdown]
# # 보고서 정상 관측치 찾기

# %%
df[df['char_refer'] == '[보고서]'].tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 33085                          부도연계 증권의 기대수익률 횡단면에 대한 연구         한국파생상품학회
# 33089                          부도연계 증권의 기대수익률 횡단면에 대한 연구         한국파생상품학회
# 36613  Does National Pension Service’s Trading Destab...           한국증권학회
# 36672  Does National Pension Service’s Trading Destab...           한국증권학회
# 36773  An Enhanced Method for Valuation of IT Investm...           한국증권학회
#
#                 author_infor                                journal_infor  \
# 33085             김정무 , 박윤정                                         선물연구
# 33089             김정무 , 박윤정                                         선물연구
# 36613             박종호 , 엄경식    Asia-Pacific Journal of Financial Studies
# 36672  고봉찬 , 이병희 , 이우종 외 1명    Asia-Pacific Journal of Financial Studies
# 36773          Beum-Jo Park    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor    page_infor  year_infor field_infor cited_infor  \
# 33085          25(4)    pp.479~508      2017.11         경영학   피인용횟수 : 0
# 33089          25(4)    pp.479~508      2017.11         경영학   피인용횟수 : 0
# 36613          37(3)    pp.501~536      2008.06         경영학  피인용횟수 : 12
# 36672          37(3)    pp.465~500      2008.06         경영학   피인용횟수 : 7
# 36773          37(4)    pp.727~763      2008.08         경영학   피인용횟수 : 1
#
#       char_refer degree_refer journal_refer    name_refer  \
# 33085      [보고서]          NaN           NaN       Kim, J.
# 33089      [보고서]          NaN           NaN   Tang, D. Y.
# 36613      [보고서]          NaN           NaN           엄경식
# 36672      [보고서]          NaN           NaN           이철용
# 36773      [보고서]          NaN           NaN         KISTI
#
#                                              paper_refer school_refer  \
# 33085  A Theory on the Expected Returns of Defautable...          NaN
# 33089         Liquidity and Credit Default Swap Spreads,          NaN
# 36613                  시간외 주식 거래: 주요국의 거래 메커니즘별 역할 및 교훈,          NaN
# 36672                              국민연금 주식투자 확대의 영향과 쟁점,          NaN
# 36773  Valuation of knowledge management office ware,...          NaN
#
#        year_refer
# 33085      2017.0
# 33089      2007.0
# 36613      2001.0
# 36672      2005.0
# 36773      2003.0

# %%
df[df['char_refer'] == '[보고서]'].isnull().sum()
# Out:
# paper_name_infor        0
# institution_infor       0
# author_infor            0
# journal_infor           0
# dont_know_infor         0
# page_infor              0
# year_infor              0
# field_infor             0
# cited_infor             0
# char_refer              0
# degree_refer         2027
# journal_refer        1966
# name_refer              1
# paper_refer             0
# school_refer         2027
# year_refer              0
# dtype: int64

# %%
journal_nan_idx = df[df['char_refer'] == '[보고서]'][df['journal_refer'].isnull()].index.tolist()
len(journal_nan_idx)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 1966

# %%
name_nan_idx = df[df['char_refer'] == '[보고서]'][df['name_refer'].isnull()].index.tolist()
len(name_nan_idx)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 1

# %%
paper_nan_idx = df[df['char_refer'] == '[보고서]'][df['paper_refer'].isnull()].index.tolist()
len(paper_nan_idx)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0

# %%
problem_idx2 = list(set(journal_nan_idx).union(set(name_nan_idx)).union(set(paper_nan_idx)))
len(problem_idx2)
# Out:
# 1966

# %%
normal_idx2 = [i for i in df[df['char_refer'] == '[보고서]'].index if i not in problem_idx2]

# %%
보고서_df = df[df['char_refer'] == '[보고서]'].loc[normal_idx2]
보고서_df.tail()
# Out:
#                        paper_name_infor institution_infor author_infor  \
# 30495  KOSPI200 지수 분산스왑 및분산위험 프리미엄 기간구조         한국파생상품학회    엄영호 , 장운욱
# 30496  KOSPI200 지수 분산스왑 및분산위험 프리미엄 기간구조         한국파생상품학회    엄영호 , 장운욱
# 30499  KOSPI200 지수 분산스왑 및분산위험 프리미엄 기간구조         한국파생상품학회    엄영호 , 장운욱
# 30504  KOSPI200 지수 분산스왑 및분산위험 프리미엄 기간구조         한국파생상품학회    엄영호 , 장운욱
# 30511  KOSPI200 지수 분산스왑 및분산위험 프리미엄 기간구조         한국파생상품학회    엄영호 , 장운욱
#
#       journal_infor dont_know_infor    page_infor  year_infor field_infor  \
# 30495         선물연구           21(4)    pp.435~463      2013.11         경영학
# 30496         선물연구           21(4)    pp.435~463      2013.11         경영학
# 30499         선물연구           21(4)    pp.435~463      2013.11         경영학
# 30504         선물연구           21(4)    pp.435~463      2013.11         경영학
# 30511         선물연구           21(4)    pp.435~463      2013.11         경영학
#
#       cited_infor char_refer degree_refer   journal_refer       name_refer  \
# 30495   피인용횟수 : 2      [보고서]          NaN  Working Paper,    Filipovic, D.
# 30496   피인용횟수 : 2      [보고서]          NaN  Working Paper,    Filipovic, D.
# 30499   피인용횟수 : 2      [보고서]          NaN  Working Paper,   Heston, Steven
# 30504   피인용횟수 : 2      [보고서]          NaN  Working Paper,     Jiang, G. J.
# 30511   피인용횟수 : 2      [보고서]          NaN  Working Paper,    Swishchuk, A.
#
#                                              paper_refer school_refer  \
# 30495                Affine Variance Swap Curve Models,           NaN
# 30496                   Quadratic Variance Swap Models,           NaN
# 30499  Derivatives on Volatility : Some Simple Soluti...          NaN
# 30504  Gauging the “Investor Fear Gauge” : Implementa...          NaN
# 30511  Modeling of Variance and Volatility Swaps for ...          NaN
#
#        year_refer
# 30495      2012.0
# 30496      2013.0
# 30499      2000.0
# 30504      2005.0
# 30511      2004.0

# %%
보고서_df.isnull().sum() , 보고서_df.shape
# Out:
# (paper_name_infor      0
#  institution_infor     0
#  author_infor          0
#  journal_infor         0
#  dont_know_infor       0
#  page_infor            0
#  year_infor            0
#  field_infor           0
#  cited_infor           0
#  char_refer            0
#  degree_refer         61
#  journal_refer         0
#  name_refer            0
#  paper_refer           0
#  school_refer         61
#  year_refer            0
#  dtype: int64, (61, 16))

# %% [markdown]
# # 기타자료 정상 관측치 찾기

# %%
df[df['char_refer'] == '[기타자료]'].tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 37155  Corporate Cash Holdings and Tax-induced Debt F...           한국증권학회
# 37180  Corporate Cash Holdings and Tax-induced Debt F...           한국증권학회
# 37196  Corporate Cash Holdings and Tax-induced Debt F...           한국증권학회
# 37211  Corporate Diversification, Relatedness, and Fi...           한국증권학회
# 37242  Corporate Diversification, Relatedness, and Fi...           한국증권학회
#
#            author_infor                                journal_infor  \
# 37155        정구열 , 김병모    Asia-Pacific Journal of Financial Studies
# 37180        정구열 , 김병모    Asia-Pacific Journal of Financial Studies
# 37196        정구열 , 김병모    Asia-Pacific Journal of Financial Studies
# 37211  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
# 37242  배성철 , 권택호 , 이장우    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor      page_infor  year_infor field_infor cited_infor  \
# 37155          37(6)     pp.983~1023      2008.12         경영학  피인용횟수 : 10
# 37180          37(6)     pp.983~1023      2008.12         경영학  피인용횟수 : 10
# 37196          37(6)     pp.983~1023      2008.12         경영학  피인용횟수 : 10
# 37211          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
# 37242          37(6)    pp.1025~1064      2008.12         경영학  피인용횟수 : 20
#
#       char_refer degree_refer journal_refer          name_refer  \
# 37155     [기타자료]          NaN           NaN       Barclay, M. J
# 37180     [기타자료]          NaN           NaN           Khanna, T
# 37196     [기타자료]          NaN           NaN          Ross, M. P
# 37211     [기타자료]          NaN           NaN      Chandler, A. D
# 37242     [기타자료]          NaN           NaN   Villalonga, Belen
#
#                                              paper_refer school_refer  \
# 37155  On the debt capacity of growth options. Unpubl...          NaN
# 37180  Emerging market business groups, foreign inves...          NaN
# 37196  Corporate hedging: What, why and how? Working ...          NaN
# 37211  The Visible Hand, Belknap Press, Cambridge, MA...          NaN
# 37242  Does Diversification Cause the “Diversificatio...          NaN
#
#        year_refer
# 37155      2001.0
# 37180      1999.0
# 37196      1997.0
# 37211      1977.0
# 37242      1999.0

# %%
df[df['char_refer'] == '[기타자료]'].isnull().sum()
# Out:
# paper_name_infor       0
# institution_infor      0
# author_infor           0
# journal_infor          0
# dont_know_infor        0
# page_infor             0
# year_infor             0
# field_infor            0
# cited_infor            0
# char_refer             0
# degree_refer         562
# journal_refer        303
# name_refer            20
# paper_refer            0
# school_refer         562
# year_refer             0
# dtype: int64

# %%
journal_nan_idx = df[df['char_refer'] == '[기타자료]'][df['journal_refer'].isnull()].index.tolist()
len(journal_nan_idx)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 303

# %%
name_nan_idx = df[df['char_refer'] == '[기타자료]'][df['name_refer'].isnull()].index.tolist()
len(name_nan_idx)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 20

# %%
paper_nan_idx = df[df['char_refer'] == '[기타자료]'][df['paper_refer'].isnull()].index.tolist()
len(paper_nan_idx)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0

# %%
problem_idx2 = list(set(journal_nan_idx).union(set(name_nan_idx)).union(set(paper_nan_idx)))
len(problem_idx2)
# Out:
# 314

# %%
normal_idx2 = [i for i in df[df['char_refer'] == '[기타자료]'].index if i not in problem_idx2]

# %%
기타자료_df = df[df['char_refer'] == '[기타자료]'].loc[normal_idx2]
기타자료_df.tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 36819  Implied Cost of Equity Capital in Earnings-Bas...           한국증권학회
# 36820  Implied Cost of Equity Capital in Earnings-Bas...           한국증권학회
# 36902  Pricing Catastrophe Derivatives Using A Recurs...           한국증권학회
# 37025  Model Selection for Estimating Portfolio VaR i...           한국증권학회
# 37118  How Does Prior Information Affect Analyst Fore...           한국증권학회
#
#                                             author_infor  \
# 36819  Sung Yoon Ahn , Seung Min Cha , Young Woo Ko 외...
# 36820  Sung Yoon Ahn , Seung Min Cha , Young Woo Ko 외...
# 36902    Yu-Hong Liu , Mao-Wei Hung , I-Ming Jiang 외 1명
# 37025                                         이상진 , 빈기범
# 37118                                               송민섭
#
#                                      journal_infor dont_know_infor  \
# 36819   Asia-Pacific Journal of Financial Studies           37(4)
# 36820   Asia-Pacific Journal of Financial Studies           37(4)
# 36902   Asia-Pacific Journal of Financial Studies           37(4)
# 37025   Asia-Pacific Journal of Financial Studies           37(5)
# 37118   Asia-Pacific Journal of Financial Studies           37(6)
#
#            page_infor  year_infor field_infor cited_infor char_refer  \
# 36819     pp.599~626      2008.08         경영학  피인용횟수 : 24     [기타자료]
# 36820     pp.599~626      2008.08         경영학  피인용횟수 : 24     [기타자료]
# 36902     pp.569~598      2008.08         경영학   피인용횟수 : 0     [기타자료]
# 37025     pp.877~912      2008.10         경영학  피인용횟수 : 10     [기타자료]
# 37118   pp.1133~1160      2008.12         경영학   피인용횟수 : 3     [기타자료]
#
#       degree_refer                                      journal_refer  \
# 36819          NaN                                     Working paper,
# 36820          NaN                                     Working paper,
# 36902          NaN                                   Working Papers),
# 37025          NaN  Board of Governors of the Federal Reserve System,
# 37118          NaN                                     Working Paper,
#
#               name_refer                                        paper_refer  \
# 36819           Hwang, L    Korean evidence on the implied cost of equity,
# 36820       Jorgensen, B  The valuation accuracy of equity value estimat...
# 36902      Cummins, J. D  An Asian option approach to the valuation of i...
# 37025   Campbell, Sean D  A Review of Backtesting and Backtesting Proced...
# 37118      Lee, Jung-Hee  Market Reactions to Business Group Analysts’ I...
#
#       school_refer  year_refer
# 36819          NaN      2007.0
# 36820          NaN      2007.0
# 36902          NaN      1993.0
# 37025          NaN      2005.0
# 37118          NaN      2007.0

# %%
기타자료_df.isnull().sum() , 기타자료_df.shape
# Out:
# (paper_name_infor       0
#  institution_infor      0
#  author_infor           0
#  journal_infor          0
#  dont_know_infor        0
#  page_infor             0
#  year_infor             0
#  field_infor            0
#  cited_infor            0
#  char_refer             0
#  degree_refer         248
#  journal_refer          0
#  name_refer             0
#  paper_refer            0
#  school_refer         248
#  year_refer             0
#  dtype: int64, (248, 16))

# %% [markdown]
# # [학위논문]

# %%
df[df['char_refer'] == '[학위논문]'].tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 32452                 우체국보험 자료를 이용한 생명보험시장의 모럴해저드에 대한 연구         한국파생상품학회
# 32453                 우체국보험 자료를 이용한 생명보험시장의 모럴해저드에 대한 연구         한국파생상품학회
# 32878   한국형 자동이체식 주택저당증권(Pass-Through MBS)에 대한 가치평가모형 개발         한국파생상품학회
# 36364  Distribution of Private Information Across Inv...           한국증권학회
# 36602  An improved approach for valuing American opti...           한국증권학회
#
#                 author_infor                                journal_infor  \
# 32452             이일주 , 이창준                                         선물연구
# 32453             이일주 , 이창준                                         선물연구
# 32878  안세륭 , 태현욱 , 서웅기 외 3명                                         선물연구
# 36364        최혁 , 이우백 , 정재만    Asia-Pacific Journal of Financial Studies
# 36602             최영수 , 송준혁    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor    page_infor  year_infor field_infor cited_infor  \
# 32452          25(1)      pp.75~95      2017.02         경영학   피인용횟수 : 0
# 32453          25(1)      pp.75~95      2017.02         경영학   피인용횟수 : 0
# 32878          25(3)    pp.305~337      2017.08         경영학   피인용횟수 : 0
# 36364          37(1)    pp.101~137      2008.02         경영학  피인용횟수 : 11
# 36602          37(2)    pp.217~244      2008.04         경영학   피인용횟수 : 1
#
#       char_refer degree_refer journal_refer    name_refer  \
# 32452     [학위논문]          NaN     국민대학교대학원,           이송우
# 32453     [학위논문]           석사           NaN           이수진
# 32878     [학위논문]           박사           NaN           한영하
# 36364     [학위논문]           박사           NaN        Low, A
# 36602     [학위논문]           박사           NaN   Averbukh, V
#
#                                              paper_refer  \
# 32452                 민영건강보험의 도덕적 해이와 본인부담금의 도입효과에 관한 연구
# 32453      민간의료보험이 의료수요에 미치는 영향 : 도덕적 해이와 역선택 효과의 실증적 구분
# 32878                  한국주택금융공사 보금자리론 조기상환율 추정 및 가치산정 연구
# 36364  Essays on asymmetric information in internatio...
# 36602  Pricing American options using Monte Carlo sim...
#
#                     school_refer  year_refer
# 32452                        NaN      2011.0
# 32453                 연세대학교 대학원,      2012.0
# 32878                 연세대학교 대학원,      2014.0
# 36364  University of California,      1992.0
# 36602        Cornell University,      1997.0

# %%
df[df['char_refer'] == '[학위논문]'].isnull().sum()
# Out:
# paper_name_infor      0
# institution_infor     0
# author_infor          0
# journal_infor         0
# dont_know_infor       0
# page_infor            0
# year_infor            0
# field_infor           0
# cited_infor           0
# char_refer            0
# degree_refer          5
# journal_refer        94
# name_refer            0
# paper_refer           0
# school_refer          5
# year_refer            0
# dtype: int64

# %% [markdown]
# 아래의 요소들이 school_refer 컬럼으로 들어가야 한다.

# %%
set(df[df['char_refer'] == '[학위논문]']['journal_refer'].tolist())
# Out:
# {nan,
#  'University of Toronto,',
#  '국민대학교대학원,',
#  'University of British Columbia,',
#  'Korea University,',
#  'The Chinese University of Hong Kong,'}

# %%
problem_idx3 = df[df['char_refer'] == '[학위논문]']['journal_refer'][df[df['char_refer'] == '[학위논문]']['journal_refer'].notnull()].index.tolist()
problem_idx3
# Out:
# [5502, 6983, 27689, 30907, 32452]

# %%
for i in problem_idx3 : 
    val = df['journal_refer'][i]
    df['school_refer'][i] = val
    df['journal_refer'][i] = np.nan
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
set(df[df['char_refer'] == '[학위논문]']['journal_refer'].tolist())
# Out:
# {nan}

# %%
df[df['char_refer'] == '[학위논문]'].isnull().sum()
# Out:
# paper_name_infor      0
# institution_infor     0
# author_infor          0
# journal_infor         0
# dont_know_infor       0
# page_infor            0
# year_infor            0
# field_infor           0
# cited_infor           0
# char_refer            0
# degree_refer          5
# journal_refer        99
# name_refer            0
# paper_refer           0
# school_refer          0
# year_refer            0
# dtype: int64

# %%
degree_refer_nan_idx = df[df['char_refer'] == '[학위논문]'][df['degree_refer'].isnull()].index.tolist()
len(degree_refer_nan_idx)
# Out:
# /home/hskimim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 5

# %%
problem_idx = degree_refer_nan_idx

# %%
normal_idx = [i for i in df[df['char_refer'] == '[학위논문]'].index if i not in problem_idx]

# %%
학위논문_df = df[df['char_refer'] == '[학위논문]'].loc[normal_idx]
학위논문_df.tail()
# Out:
#                                         paper_name_infor institution_infor  \
# 32447                 우체국보험 자료를 이용한 생명보험시장의 모럴해저드에 대한 연구         한국파생상품학회
# 32453                 우체국보험 자료를 이용한 생명보험시장의 모럴해저드에 대한 연구         한국파생상품학회
# 32878   한국형 자동이체식 주택저당증권(Pass-Through MBS)에 대한 가치평가모형 개발         한국파생상품학회
# 36364  Distribution of Private Information Across Inv...           한국증권학회
# 36602  An improved approach for valuing American opti...           한국증권학회
#
#                 author_infor                                journal_infor  \
# 32447             이일주 , 이창준                                         선물연구
# 32453             이일주 , 이창준                                         선물연구
# 32878  안세륭 , 태현욱 , 서웅기 외 3명                                         선물연구
# 36364        최혁 , 이우백 , 정재만    Asia-Pacific Journal of Financial Studies
# 36602             최영수 , 송준혁    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor    page_infor  year_infor field_infor cited_infor  \
# 32447          25(1)      pp.75~95      2017.02         경영학   피인용횟수 : 0
# 32453          25(1)      pp.75~95      2017.02         경영학   피인용횟수 : 0
# 32878          25(3)    pp.305~337      2017.08         경영학   피인용횟수 : 0
# 36364          37(1)    pp.101~137      2008.02         경영학  피인용횟수 : 11
# 36602          37(2)    pp.217~244      2008.04         경영학   피인용횟수 : 1
#
#       char_refer degree_refer journal_refer    name_refer  \
# 32447     [학위논문]           석사           NaN           김동현
# 32453     [학위논문]           석사           NaN           이수진
# 32878     [학위논문]           박사           NaN           한영하
# 36364     [학위논문]           박사           NaN        Low, A
# 36602     [학위논문]           박사           NaN   Averbukh, V
#
#                                              paper_refer  \
# 32447                         국내 민간의료보험 시장의 역선택에 관한 실증연구
# 32453      민간의료보험이 의료수요에 미치는 영향 : 도덕적 해이와 역선택 효과의 실증적 구분
# 32878                  한국주택금융공사 보금자리론 조기상환율 추정 및 가치산정 연구
# 36364  Essays on asymmetric information in internatio...
# 36602  Pricing American options using Monte Carlo sim...
#
#                     school_refer  year_refer
# 32447                 경희대학교 대학원,      2008.0
# 32453                 연세대학교 대학원,      2012.0
# 32878                 연세대학교 대학원,      2014.0
# 36364  University of California,      1992.0
# 36602        Cornell University,      1997.0

# %%
학위논문_df.isnull().sum() , 학위논문_df.shape
# Out:
# (paper_name_infor      0
#  institution_infor     0
#  author_infor          0
#  journal_infor         0
#  dont_know_infor       0
#  page_infor            0
#  year_infor            0
#  field_infor           0
#  cited_infor           0
#  char_refer            0
#  degree_refer          0
#  journal_refer        94
#  name_refer            0
#  paper_refer           0
#  school_refer          0
#  year_refer            0
#  dtype: int64, (94, 16))

# %% [markdown]
# # CONCATENATE

# %%
df1,df2,df3,df4,df5,df6 = 학술대회논문_df , 학술지_df , 학위논문_df , 보고서_df , 단행본_df , 기타자료_df

# %%
학술대회논문_df.shape , 학술지_df.shape , 학위논문_df.shape , 보고서_df.shape , 단행본_df.shape , 기타자료_df.shape
# Out:
# ((383, 16), (27462, 16), (94, 16), (61, 16), (1027, 16), (248, 16))

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6], ignore_index=True)
df.isnull().sum()
# Out:
# paper_name_infor         0
# institution_infor        0
# author_infor             0
# journal_infor            0
# dont_know_infor          0
# page_infor               0
# year_infor               0
# field_infor              0
# cited_infor              0
# char_refer               0
# degree_refer         29181
# journal_refer           94
# name_refer               0
# paper_refer              0
# school_refer         29181
# year_refer               0
# dtype: int64

# %%
idx_ls = []
for idx,val in enumerate(df['paper_refer']):
    if type(val) == str :
        if len(val) < 5 :
            idx_ls.append(idx)
len(idx_ls)
# Out:
# 28

# %%
df.loc[idx_ls]
# Out:
#                                         paper_name_infor institution_infor  \
# 5735                      절대고유수익률과 미래 주식수익률의 관계에 관한 실증연구           한국증권학회
# 11533                            자사주 취득과 내부자 거래의 정보신호 효과           한국재무학회
# 12704                            자사주 취득과 내부자 거래의 정보신호 효과           한국재무학회
# 14454                              R2와 기업가치의 관계에 관한 실증연구         한국재무관리학회
# 19021                                         주식분할의 장기성과         한국재무관리학회
# 19023                                         주식분할의 장기성과         한국재무관리학회
# 19025                                         주식분할의 장기성과         한국재무관리학회
# 19026                                         주식분할의 장기성과         한국재무관리학회
# 19028                                         주식분할의 장기성과         한국재무관리학회
# 19035                                         주식분할의 장기성과         한국재무관리학회
# 19037                                         주식분할의 장기성과         한국재무관리학회
# 19038                                         주식분할의 장기성과         한국재무관리학회
# 19058                                유배당보험상품에 대한 재무론적 분석         한국재무관리학회
# 19062                                유배당보험상품에 대한 재무론적 분석         한국재무관리학회
# 19074    주가지수 선물과 옵션의 만기일이 주식시장에 미치는 영향 : 개별 종목 분석을 중심으로         한국재무관리학회
# 19075    주가지수 선물과 옵션의 만기일이 주식시장에 미치는 영향 : 개별 종목 분석을 중심으로         한국재무관리학회
# 19094                  소유경영자지분율과 자본구조 : 외환위기 이후기간 패널자료분석         한국재무관리학회
# 19098                  소유경영자지분율과 자본구조 : 외환위기 이후기간 패널자료분석         한국재무관리학회
# 19100                  소유경영자지분율과 자본구조 : 외환위기 이후기간 패널자료분석         한국재무관리학회
# 19102                  소유경영자지분율과 자본구조 : 외환위기 이후기간 패널자료분석         한국재무관리학회
# 19129                  불완전자본시장 하에서 은행의 유가증권 보유 동기에 관한 연구         한국재무관리학회
# 19139                       한국주식시장에 파급되는 국제유가의 위험에 관한 연구         한국재무관리학회
# 19140                       한국주식시장에 파급되는 국제유가의 위험에 관한 연구         한국재무관리학회
# 19142                       한국주식시장에 파급되는 국제유가의 위험에 관한 연구         한국재무관리학회
# 19153               코스닥 상장법인의 소유구조 및 사외이사와기업가치 간의 관련성 분석         한국재무관리학회
# 19155               코스닥 상장법인의 소유구조 및 사외이사와기업가치 간의 관련성 분석         한국재무관리학회
# 22964                             우리나라 옵션시장의 불완전성에 대한 연구         한국파생상품학회
# 27305  Which Idiosyncratic Factors Can Explain the Pr...           한국증권학회
#
#            author_infor                                journal_infor  \
# 5735          김류미 , 채준                                      한국증권학회지
# 11533  윤평식 , 임병권 , 박순홍                                         재무연구
# 12704  윤평식 , 임병권 , 박순홍                                         재무연구
# 14454        고봉찬 , 김류미                                       재무관리연구
# 19021        변종국 , 조정일                                       재무관리연구
# 19023        변종국 , 조정일                                       재무관리연구
# 19025        변종국 , 조정일                                       재무관리연구
# 19026        변종국 , 조정일                                       재무관리연구
# 19028        변종국 , 조정일                                       재무관리연구
# 19035        변종국 , 조정일                                       재무관리연구
# 19037        변종국 , 조정일                                       재무관리연구
# 19038        변종국 , 조정일                                       재무관리연구
# 19058  이건호 , 위경우 , 전상경                                       재무관리연구
# 19062  이건호 , 위경우 , 전상경                                       재무관리연구
# 19074         최혁 , 엄윤성                                       재무관리연구
# 19075         최혁 , 엄윤성                                       재무관리연구
# 19094        김병곤 , 김동욱                                       재무관리연구
# 19098        김병곤 , 김동욱                                       재무관리연구
# 19100        김병곤 , 김동욱                                       재무관리연구
# 19102        김병곤 , 김동욱                                       재무관리연구
# 19129              신보성                                       재무관리연구
# 19139              서지용                                       재무관리연구
# 19140              서지용                                       재무관리연구
# 19142              서지용                                       재무관리연구
# 19153              박범진                                       재무관리연구
# 19155              박범진                                       재무관리연구
# 22964        현정순 , 이병근                                         선물연구
# 27305         채준 , 양철원    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor      page_infor  year_infor field_infor cited_infor  \
# 5735           44(5)    pp.1031~1063      2015.12         경영학   피인용횟수 : 1
# 11533          28(3)      pp.351~384      2015.08         경영학   피인용횟수 : 6
# 12704          28(3)      pp.351~384      2015.08         경영학   피인용횟수 : 6
# 14454          29(3)      pp.177~202      2012.09         경영학   피인용횟수 : 5
# 19021          24(1)         pp.1~27      2007.03         경영학  피인용횟수 : 13
# 19023          24(1)         pp.1~27      2007.03         경영학  피인용횟수 : 13
# 19025          24(1)         pp.1~27      2007.03         경영학  피인용횟수 : 13
# 19026          24(1)         pp.1~27      2007.03         경영학  피인용횟수 : 13
# 19028          24(1)         pp.1~27      2007.03         경영학  피인용횟수 : 13
# 19035          24(1)         pp.1~27      2007.03         경영학  피인용횟수 : 13
# 19037          24(1)         pp.1~27      2007.03         경영학  피인용횟수 : 13
# 19038          24(1)         pp.1~27      2007.03         경영학  피인용횟수 : 13
# 19058          24(2)      pp.147~181      2007.06         경영학   피인용횟수 : 0
# 19062          24(2)      pp.147~181      2007.06         경영학   피인용횟수 : 0
# 19074          24(2)        pp.41~79      2007.06         경영학   피인용횟수 : 7
# 19075          24(2)        pp.41~79      2007.06         경영학   피인용횟수 : 7
# 19094          24(2)       pp.81~111      2007.06         경영학  피인용횟수 : 23
# 19098          24(2)       pp.81~111      2007.06         경영학  피인용횟수 : 23
# 19100          24(2)       pp.81~111      2007.06         경영학  피인용횟수 : 23
# 19102          24(2)       pp.81~111      2007.06         경영학  피인용횟수 : 23
# 19129          24(3)         pp.1~27      2007.09         경영학   피인용횟수 : 1
# 19139          24(4)       pp.75~106      2007.12         경영학  피인용횟수 : 17
# 19140          24(4)       pp.75~106      2007.12         경영학  피인용횟수 : 17
# 19142          24(4)       pp.75~106      2007.12         경영학  피인용횟수 : 17
# 19153          24(4)        pp.45~73      2007.12         경영학  피인용횟수 : 38
# 19155          24(4)        pp.45~73      2007.12         경영학  피인용횟수 : 38
# 22964          12(2)        pp.25~43      2004.11         경영학  피인용횟수 : 10
# 27305          37(2)      pp.297~342      2008.04         경영학   피인용횟수 : 6
#
#          char_refer degree_refer  \
# 5735   [학술지(정기간행물)]          NaN
# 11533  [학술지(정기간행물)]          NaN
# 12704  [학술지(정기간행물)]          NaN
# 14454  [학술지(정기간행물)]          NaN
# 19021  [학술지(정기간행물)]          NaN
# 19023  [학술지(정기간행물)]          NaN
# 19025  [학술지(정기간행물)]          NaN
# 19026  [학술지(정기간행물)]          NaN
# 19028  [학술지(정기간행물)]          NaN
# 19035  [학술지(정기간행물)]          NaN
# 19037  [학술지(정기간행물)]          NaN
# 19038  [학술지(정기간행물)]          NaN
# 19058  [학술지(정기간행물)]          NaN
# 19062  [학술지(정기간행물)]          NaN
# 19074  [학술지(정기간행물)]          NaN
# 19075  [학술지(정기간행물)]          NaN
# 19094  [학술지(정기간행물)]          NaN
# 19098  [학술지(정기간행물)]          NaN
# 19100  [학술지(정기간행물)]          NaN
# 19102  [학술지(정기간행물)]          NaN
# 19129  [학술지(정기간행물)]          NaN
# 19139  [학술지(정기간행물)]          NaN
# 19140  [학술지(정기간행물)]          NaN
# 19142  [학술지(정기간행물)]          NaN
# 19153  [학술지(정기간행물)]          NaN
# 19155  [학술지(정기간행물)]          NaN
# 22964  [학술지(정기간행물)]          NaN
# 27305  [학술지(정기간행물)]          NaN
#
#                                            journal_refer      name_refer  \
# 5735                  Journal of Finance 43 : 541 ~ 566,        Roll, R.
# 11533                 Journal of Finance 43 : 541 ~ 566,        Roll, R.
# 12704                 Journal of Finance 43 : 541 ~ 566,        Roll, R.
# 14454                 Journal of Finance 43 : 541 ~ 566,        Roll, R.
# 19021                    Journal of Finance : 533 ~ 553,               Y
# 19023        Journal of Financial Economics : 281 ~ 305,         Barclay
# 19025            Journal of Finance “ (ise) : 529 ~ 543,        Black. F
# 19026         Journal of Financial Economics : 83 ~ 101,         Brennan
# 19028        Journal of Financial Economics : 265 ~ 296,         Charest
# 19035                    Journal of Finance : 913 ~ 932,               J
# 19037                    Journal of Finance : 857 ~ 879,       McNichols
# 19038                    Journal of Finance : 857 ~ 879,       McNichols
# 19058                     Journal of Business : 29 ~ 46,          Starks
# 19062         Journal of Risk and Insurance : 638 ~ 655,          Mayers
# 19074                      Journal of Finance : 77 ~ 99,          Harris
# 19075            Journal of Futures Markets : 323 ~ 325,          Herbst
# 19094                      Journal of Finance : 13 ~ 31,          Hamada
# 19098                    Journal of Finance : 371 ~ 387,          Leland
# 19100  Journal of Financial and Quantitative Analysis...               H
# 19102          Journal of Political Economy : 461 ~ 488,          Andrei
# 19129  Journal of Banking and Finance 14 sofia (s) : ...          George
# 19139                   Journal of Business : 383 ~ 403,            Chen
# 19140                    Journal of Finance : 529 ~ 554,            Chen
# 19142                  Journal of Finance : 1089 ~ 1108,            Fama
# 19153          Journal of Political Economy : 225 ~ 264,          Jensen
# 19155        Journal of Financial Economics : 293 ~ 315,           Morck
# 22964                     Journal of Finance : 771 ~ 818      Rubinstein
# 27305                 Journal of Finance 43 : 541 ~ 566,   Roll, Richard
#
#       paper_refer school_refer  year_refer
# 5735           /           NaN      1988.0
# 11533          R2          NaN      1988.0
# 12704          R2          NaN      1988.0
# 14454         R^2          NaN      1988.0
# 19021          ”           NaN      1987.0
# 19023          ”           NaN      1993.0
# 19025          ”           NaN      1986.0
# 19026          ”           NaN      1988.0
# 19028          ”           NaN      1978.0
# 19035          ”           NaN      1987.0
# 19037          ”           NaN      1990.0
# 19038          ”           NaN      1990.0
# 19058          ”           NaN      1993.0
# 19062          ”           NaN      1994.0
# 19074          ”           NaN      1989.0
# 19075          ”           NaN      1990.0
# 19094          ”           NaN      1969.0
# 19098          ”           NaN      1977.0
# 19100          ”           NaN      1992.0
# 19102          ”           NaN      1986.0
# 19129          ”           NaN      1990.0
# 19139          ”           NaN      1986.0
# 19140          ”           NaN      1991.0
# 19142          ”           NaN      1990.0
# 19153          ”           NaN      1990.0
# 19155          ”           NaN      1988.0
# 22964          ”           NaN      1994.0
# 27305          R2          NaN      1988.0

# %%
new_idx_ls = [idx for idx,val in enumerate(df['paper_refer']) if (type(val) == str) and ((val == '/ ') or (val == '” ')or (val == '” '))]
new_idx_ls[:5]
# Out:
# [5735, 19021, 19023, 19025, 19026]

# %%
df = df.loc[[i for i in df.index if i not in new_idx_ls]].reset_index(drop=True)
df.shape
# Out:
# (29251, 16)

# %%
idx_ls = []
for idx,val in enumerate(df['paper_refer']):
    if type(val) == str :
        if len(val) < 5 :
            idx_ls.append(idx)
len(idx_ls)
# Out:
# 4

# %%
df.loc[idx_ls]
# Out:
#                                         paper_name_infor institution_infor  \
# 11532                            자사주 취득과 내부자 거래의 정보신호 효과           한국재무학회
# 12703                            자사주 취득과 내부자 거래의 정보신호 효과           한국재무학회
# 14453                              R2와 기업가치의 관계에 관한 실증연구         한국재무관리학회
# 27281  Which Idiosyncratic Factors Can Explain the Pr...           한국증권학회
#
#            author_infor                                journal_infor  \
# 11532  윤평식 , 임병권 , 박순홍                                         재무연구
# 12703  윤평식 , 임병권 , 박순홍                                         재무연구
# 14453        고봉찬 , 김류미                                       재무관리연구
# 27281         채준 , 양철원    Asia-Pacific Journal of Financial Studies
#
#       dont_know_infor    page_infor  year_infor field_infor cited_infor  \
# 11532          28(3)    pp.351~384      2015.08         경영학   피인용횟수 : 6
# 12703          28(3)    pp.351~384      2015.08         경영학   피인용횟수 : 6
# 14453          29(3)    pp.177~202      2012.09         경영학   피인용횟수 : 5
# 27281          37(2)    pp.297~342      2008.04         경영학   피인용횟수 : 6
#
#          char_refer degree_refer                       journal_refer  \
# 11532  [학술지(정기간행물)]          NaN  Journal of Finance 43 : 541 ~ 566,
# 12703  [학술지(정기간행물)]          NaN  Journal of Finance 43 : 541 ~ 566,
# 14453  [학술지(정기간행물)]          NaN  Journal of Finance 43 : 541 ~ 566,
# 27281  [학술지(정기간행물)]          NaN  Journal of Finance 43 : 541 ~ 566,
#
#            name_refer paper_refer school_refer  year_refer
# 11532        Roll, R.          R2          NaN      1988.0
# 12703        Roll, R.          R2          NaN      1988.0
# 14453        Roll, R.         R^2          NaN      1988.0
# 27281   Roll, Richard          R2          NaN      1988.0

# %%
df.to_csv('stricted_filtered_final_df.csv',index=False)
